# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

# 텍스트로 이루어진 문장을 단순하게 숫자의 나열로 변환시키고, 단어는 빈도수가 많은 것을 중심으로 사전을 구성한다.
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
#     print(dictionary[word])
    
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)

  count[0][1] = unk_count

  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.123363
# Nearest to it: godless, neale, fis, factoring, ats, ferromagnetism, baryonic, chapel,
# Nearest to seven: cask, epsilon, surrealism, dinners, latour, annexed, sonar, mun,
# Nearest to at: liberalism, puppeteer, chivalry, flyby, sds, patched, endocrine, ssr,
# Nearest to in: mcgill, pullback, scooby, racks, trapezohedron, domination, regiments, montane,
# Nearest to an: friedrich, excelling, dalnet, beset, heflin, puccini, afewerki, lundy,
# Nearest to have: targeted, mitchell, required, nightlife, sensors, surjective, past, mifflin,
# Nearest to been: djamena, barkley, jagiellon, zoroastrians, msi, preamble, devolved, vader,
# Nearest to d: ssl, conjectured, ambitious, foundational, hitomaro, basal, cosmologies, simile,
# Nearest to than: uniformitarianism, typewriter, interact, croat, plantations, manure, mathematica, inxs,
# Nearest to zero: acute, romances, coordinator, atheromatous, frisia, principe, resides, carboxylic,
# Nearest to for: normalised, murdock, willson, sa, insider, kuiper, hasbro, pans,
# Nearest to four: transatlantic, euthanasia, nagorno, grease, glazed, terran, moribund, basso,
# Nearest to two: establishing, intelligent, computes, dcsd, gilmour, freer, intrinsically, purcell,
# Nearest to the: aqdas, howto, constrain, batu, quarterbacks, municipality, undertakes, babylonia,
# Nearest to so: reich, matador, ellesmere, niro, hospitality, mathematica, befitting, crb,
# Nearest to called: kinky, remastered, birley, collectivity, faltering, titanic, manhattan, swansea,
# Average loss at step 2000: 4.375620
# Average loss at step 4000: 3.859033
# Average loss at step 6000: 3.785274
# Average loss at step 8000: 3.688674
# Average loss at step 10000: 3.623754
# Nearest to it: he, there, this, she, not, which, they, that,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to at: in, smiling, on, ontario, puppeteer, of, by, prefrontal,
# Nearest to in: on, of, at, with, nepalese, after, by, for,
# Nearest to an: rifled, athletes, this, the, fielder, friedrich, aquifer, persuading,
# Nearest to have: has, had, be, are, were, required, do, hjalmar,
# Nearest to been: was, contemptuous, finale, jagiellon, often, had, venetian, strau,
# Nearest to d: ssl, basal, foundational, american, b, megafauna, cosmologies, flair,
# Nearest to than: amphitheatre, acquaintance, conservative, puts, pony, forecast, cinematographer, millie,
# Nearest to zero: eight, seven, six, five, nine, four, three, two,
# Nearest to for: exaggeration, of, cond, with, vet, few, in, after,
# Nearest to four: eight, six, five, three, seven, two, zero, nine,
# Nearest to two: three, five, four, one, six, eight, seven, zero,
# Nearest to the: its, their, this, a, his, quarterbacks, lascaux, petrarch,
# Nearest to so: hospitality, reich, time, daylights, interfered, matador, maryam, though,
# Nearest to called: dunwich, traditionally, manhattan, busan, remastered, brownish, collectivity, kojiki,
# Average loss at step 12000: 3.600862
# Average loss at step 14000: 3.576009
# Average loss at step 16000: 3.406405
# Average loss at step 18000: 3.462267
# Average loss at step 20000: 3.542622
# Nearest to it: he, this, there, she, which, they, not, often,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to at: in, on, and, smiling, from, havelock, with, when,
# Nearest to in: on, at, during, with, and, from, through, until,
# Nearest to an: the, another, fielder, rifled, beset, athletes, aquifer, fermanagh,
# Nearest to have: had, has, are, were, be, strongly, keeling, zander,
# Nearest to been: be, by, finale, become, contemptuous, blogger, venetian, had,
# Nearest to d: b, illegally, kills, foundational, ssl, cosmologies, unwin, basal,
# Nearest to than: or, conservative, sinking, millie, puts, hler, cinematographer, jehoiachin,
# Nearest to zero: five, six, seven, four, eight, three, nine, two,
# Nearest to for: vet, downy, by, cond, or, with, as, hera,
# Nearest to four: six, three, seven, five, two, eight, nine, zero,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to the: their, its, quarterbacks, a, this, an, his, another,
# Nearest to so: reich, hospitality, matador, nilotic, maryam, paralleled, honecker, interfered,
# Nearest to called: traditionally, dunwich, dim, zarah, remastered, busan, manhattan, starter,
# Average loss at step 22000: 3.501965
# Average loss at step 24000: 3.491820
# Average loss at step 26000: 3.485139
# Average loss at step 28000: 3.482446
# Average loss at step 30000: 3.502401
# Nearest to it: he, she, there, this, they, bankers, which, often,
# Nearest to seven: eight, five, nine, four, six, three, zero, one,
# Nearest to at: in, havelock, hif, smiling, ginza, bokken, punter, on,
# Nearest to in: on, of, at, from, during, and, around, with,
# Nearest to an: athletes, shipments, heflin, esteban, obadiah, rifled, fielder, hertogenbosch,
# Nearest to have: had, has, are, be, were, lymphoma, having, zander,
# Nearest to been: become, be, was, finale, were, contemptuous, bought, instrumentalists,
# Nearest to d: b, kills, illegally, unwin, spiritualist, basal, foundational, pedagogic,
# Nearest to than: millie, hler, sinking, gellius, puts, hillside, pia, conservative,
# Nearest to zero: eight, five, seven, four, nine, six, three, two,
# Nearest to for: after, mariah, cond, communists, with, transpose, transfered, downy,
# Nearest to four: five, eight, six, three, seven, two, nine, zero,
# Nearest to two: four, one, three, five, eight, seven, six, nine,
# Nearest to the: their, its, his, some, a, quarterbacks, her, many,
# Nearest to so: maryam, borax, nilotic, paralleled, jacobin, crazed, matador, interfered,
# Nearest to called: dunwich, diogenes, starter, zarah, garner, rgermeister, traditionally, dim,
# Average loss at step 32000: 3.507826
# Average loss at step 34000: 3.493673
# Average loss at step 36000: 3.456273
# Average loss at step 38000: 3.302082
# Average loss at step 40000: 3.431362
# Nearest to it: he, there, she, this, bankers, they, not, which,
# Nearest to seven: eight, five, six, nine, four, three, zero, one,
# Nearest to at: during, on, in, havelock, kenner, hif, cereals, wiesenthal,
# Nearest to in: of, with, on, during, between, since, coax, at,
# Nearest to an: athletes, fermanagh, another, moore, esteban, tonkin, heavily, rifled,
# Nearest to have: has, had, were, be, are, lymphoma, include, hjalmar,
# Nearest to been: become, be, was, were, had, bought, being, contemptuous,
# Nearest to d: b, illegally, kills, unwin, lla, shen, cathode, worshippers,
# Nearest to than: or, but, millie, much, puts, hler, gellius, haifa,
# Nearest to zero: seven, five, nine, eight, four, six, three, two,
# Nearest to for: communists, cond, with, in, musicologist, by, from, vociferous,
# Nearest to four: three, six, eight, five, seven, two, nine, one,
# Nearest to two: three, four, five, six, seven, one, zero, eight,
# Nearest to the: their, this, its, any, a, quarterbacks, some, his,
# Nearest to so: borax, paralleled, crazed, nilotic, maryam, interfered, gregers, jacobin,
# Nearest to called: dunwich, named, garner, diogenes, starter, gy, mishna, traditionally,
# Average loss at step 42000: 3.437193
# Average loss at step 44000: 3.453214
# Average loss at step 46000: 3.453474
# Average loss at step 48000: 3.347341
# Average loss at step 50000: 3.387407
# Nearest to it: he, there, she, this, they, bankers, often, now,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to at: around, during, hif, in, smiling, disparity, havelock, between,
# Nearest to in: during, throughout, since, from, of, and, on, under,
# Nearest to an: athletes, obadiah, rifled, heflin, another, tonkin, lope, moore,
# Nearest to have: had, has, were, are, be, having, never, include,
# Nearest to been: become, be, was, contemptuous, were, had, being, instrumentalists,
# Nearest to d: b, lla, kills, cathode, basal, illegally, emulsifiers, shen,
# Nearest to than: or, but, gellius, much, and, drinking, truro, pia,
# Nearest to zero: seven, eight, five, four, nine, six, three, two,
# Nearest to for: mariah, cond, including, hipc, transpose, while, musicologist, downy,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to two: three, four, eight, one, six, seven, five, nine,
# Nearest to the: its, this, their, any, his, a, persuading, gershwin,
# Nearest to so: nilotic, maryam, paralleled, gregers, interfered, prayed, if, kendo,
# Nearest to called: named, dunwich, mishna, garner, diogenes, claus, dim, promulgation,
# Average loss at step 52000: 3.437158
# Average loss at step 54000: 3.432129
# Average loss at step 56000: 3.440079
# Average loss at step 58000: 3.394649
# Average loss at step 60000: 3.397321
# Nearest to it: he, there, she, this, they, bankers, what, which,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to at: in, during, havelock, darshan, smiling, hif, within, gliders,
# Nearest to in: throughout, during, at, within, of, between, since, among,
# Nearest to an: rifled, athletes, festival, esteban, shipments, lope, fielder, tonkin,
# Nearest to have: had, has, are, were, having, be, include, sihanouk,
# Nearest to been: become, be, were, was, contemptuous, had, sac, cartridges,
# Nearest to d: b, lla, emulsifiers, kills, cathode, c, unwin, iru,
# Nearest to than: or, much, truro, jacobins, gellius, and, pia, but,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to for: cond, of, including, transpose, tragedies, if, actual, after,
# Nearest to four: six, five, three, eight, seven, nine, zero, two,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to the: its, their, a, some, this, knitting, his, each,
# Nearest to so: interfered, too, paralleled, if, nilotic, jacobin, kendo, borax,
# Nearest to called: named, garner, dunwich, used, diogenes, mishna, considered, ventricles,
# Average loss at step 62000: 3.239741
# Average loss at step 64000: 3.252168
# Average loss at step 66000: 3.408032
# Average loss at step 68000: 3.396027
# Average loss at step 70000: 3.360796
# Nearest to it: he, there, she, this, they, bankers, often, usually,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to at: during, havelock, darshan, in, lifes, within, smiling, after,
# Nearest to in: within, during, on, among, for, including, from, of,
# Nearest to an: the, athletes, esteban, rifled, shipments, another, heflin, roanoke,
# Nearest to have: had, has, are, were, having, be, include, bosch,
# Nearest to been: become, be, was, were, recently, previously, cartridges, already,
# Nearest to d: b, lla, kills, cathode, dragonfly, emulsifiers, ramon, iru,
# Nearest to than: or, pia, much, gellius, significantly, truro, millie, evils,
# Nearest to zero: five, eight, six, four, seven, nine, three, two,
# Nearest to for: including, in, without, hipc, while, cond, proxima, to,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to two: three, four, six, seven, one, five, zero, eight,
# Nearest to the: their, its, a, any, this, these, deviate, another,
# Nearest to so: thus, too, if, covalent, interfered, sometimes, drilled, nilotic,
# Nearest to called: named, diogenes, used, ventricles, mishna, dunwich, considered, known,
# Average loss at step 72000: 3.373439
# Average loss at step 74000: 3.350954
# Average loss at step 76000: 3.320967
# Average loss at step 78000: 3.351741
# Average loss at step 80000: 3.378746
# Nearest to it: he, she, there, this, they, never, we, bankers,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to at: during, hif, havelock, lifes, crescas, in, smiling, auteur,
# Nearest to in: during, within, on, until, since, throughout, prostate, tying,
# Nearest to an: athletes, esteban, obadiah, another, roanoke, lope, bithynia, asb,
# Nearest to have: had, has, were, are, having, include, be, provide,
# Nearest to been: become, be, was, were, being, recently, cartridges, blogger,
# Nearest to d: b, cathode, lla, preferable, kills, illegally, dragonfly, gwh,
# Nearest to than: or, much, significantly, gellius, canonised, pia, truro, even,
# Nearest to zero: five, seven, eight, six, four, three, nine, two,
# Nearest to for: including, after, cond, exaggeration, hipc, during, downy, proxima,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to the: its, their, a, this, quarterbacks, each, his, cullen,
# Nearest to so: too, thus, nilotic, if, therefore, lumley, however, jacobin,
# Nearest to called: named, known, considered, diogenes, used, mishna, tasmanian, dunwich,
# Average loss at step 82000: 3.414234
# Average loss at step 84000: 3.411826
# Average loss at step 86000: 3.388229
# Average loss at step 88000: 3.357082
# Average loss at step 90000: 3.366401
# Nearest to it: he, she, there, this, they, often, bankers, usually,
# Nearest to seven: eight, six, nine, five, four, three, one, zero,
# Nearest to at: during, hif, lifes, around, in, havelock, after, on,
# Nearest to in: within, during, until, under, between, around, at, on,
# Nearest to an: athletes, esteban, another, bithynia, fermanagh, festival, duc, brokers,
# Nearest to have: had, has, were, are, include, be, having, elisabetta,
# Nearest to been: become, be, was, being, already, recently, previously, contemptuous,
# Nearest to d: b, lla, cathode, iru, dragonfly, pelagius, spiritualist, illegally,
# Nearest to than: pia, or, canonised, much, gellius, strewn, significantly, slovene,
# Nearest to zero: eight, five, seven, nine, six, four, three, two,
# Nearest to for: including, after, while, of, hipc, without, against, proxima,
# Nearest to four: five, three, seven, six, eight, two, nine, one,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to the: its, this, their, his, a, quarterbacks, her, any,
# Nearest to so: too, thus, gregers, if, then, therefore, elohim, lumley,
# Nearest to called: named, known, used, considered, mishna, referred, diogenes, ventricles,
# Average loss at step 92000: 3.398624
# Average loss at step 94000: 3.257254
# Average loss at step 96000: 3.357478
# Average loss at step 98000: 3.248993
# Average loss at step 100000: 3.357213
# Nearest to it: he, she, this, there, they, never, often, bankers,
# Nearest to seven: eight, five, four, six, nine, three, zero, two,
# Nearest to at: during, on, in, auteur, within, after, darshan, havelock,
# Nearest to in: during, within, on, throughout, until, from, at, among,
# Nearest to an: another, athletes, esteban, voiceover, baghdad, duc, amoxicillin, tonkin,
# Nearest to have: had, has, are, were, include, having, be, wish,
# Nearest to been: become, be, was, recently, already, being, contemptuous, previously,
# Nearest to d: b, foundational, cathode, iru, kills, usr, basal, c,
# Nearest to than: or, pia, slovene, much, significantly, gellius, canonised, even,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to for: including, hipc, without, if, after, while, against, downy,
# Nearest to four: five, seven, six, eight, nine, three, zero, two,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to the: their, its, his, a, each, quarterbacks, your, this,
# Nearest to so: thus, then, too, therefore, when, gregers, sometimes, if,
# Nearest to called: named, known, mishna, used, ventricles, convulsions, referred, accompanied,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
